# %% [markdown]
# Starting off with Colab :  Connect and run the notebook
#
# 1. Select **Connect** near the top-right corner of Colab.
# 2. Wait until Colab reports that the runtime is connected.
# 3. Run the **Colab Setup Check** code cell below by selecting its play button.
# 4. Confirm that the following message appears beneath the cell:
#
# ```text
# Google Colab is set up and ready!
# ```

# %%
# ============================================================
# Colab Setup Check
# ============================================================

# You will run this cell after importing the notebook into Colab.
#
# If the cell runs successfully, Colab is ready to execute Python.

print("Google Colab is set up and ready!")

# %% [markdown]
# ### Part 4 – Edit the notebook
#
# Complete the code cell below by entering your name. Run it and confirm that the output is correct.

# %%
# Replace the placeholder text with your name.

student_name = "YOUR NAME HERE"

print("Notebook imported and run successfully by:", student_name)

# %% [markdown]
# Save Your Work
#
# Colab normally saves changes to Google Drive only when you are working with a Drive copy. To keep your completed work, use one of these options:
#
# - Select **File → Save a copy in Drive** to create a copy in your Google Drive.
# - Select **File → Download → Download .ipynb** to save the updated notebook to your computer.
#
# Before finishing, verify that:
#
# - [ ] The notebook opened successfully in Colab.
# - [ ] The runtime connected.
# - [ ] Both code cells ran without errors.
# - [ ] Your name appeared in the final output.
# - [ ] You saved or downloaded the completed notebook.
#
# Submit the completed `.ipynb` file.
