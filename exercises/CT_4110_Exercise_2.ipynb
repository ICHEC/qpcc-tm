# %% [markdown]
# ## CT4110 – Topic 2 - From Bits to Qubits

# %% [markdown]
# ### Exercise 1 - Ungraded Setup Task – Google Colab
#
# From Topic 3 onwards we will be using Jupyter Notebooks (.ipynb) for providing coding assignments,You could use a local python to solve these assignments but if this is your first time coding we'd prefer you starting on Google Colab. Google Colab allows you to run Jupyter notebooks in a web browser without installing Python on your computer.
#
# In this short task, you will learn how to:
#
# - Open Google Colab.
# - Import a downloaded `.ipynb` notebook.
# - Connect to a Colab runtime.
# - Run notebook cells.
# - Save or download your completed notebook.
#
# > **This setup task is ungraded.** The graded Topic 2 assignment begins later in this document.
#
# > If you face any issues while setting up colab, ping us on the qpcc email.

# %% [markdown]
# ## Task – Import and Run a Downloaded Notebook
#
# Follow these steps:
#
# ### Part 1 – Download the notebook
#
# 1. Download the `.ipynb` by clicking the following link <a href="../assets/notebooks/Colab_test.ipynb" download>Download Colab setup notebook</a>.
# 2. Check that the filename ends in `.ipynb`.
# 3. Note where the file was saved on your computer, usually the **Downloads** folder.
#
# ### Part 2 – Open Google Colab
#
# 1. Open [Google Colab](https://colab.research.google.com/) in a web browser.
# 2. Sign in with a Google account if requested.
# 3. In the **Open notebook** window, select the **Upload** tab.
#    - If that window is not visible, select **File → Upload notebook**.
# 4. Choose **Browse**, locate the downloaded `.ipynb` file, and open it.
# 5. Wait for the notebook to appear in Colab.
#
# ### Part 3 - Connecting to a runtime and running code
#
# 1. Follow the instructions as shown in the colab file to learn how to connect a runtime and run code blocks in colab
# 2. Save the colab file and submit it as ipynb to the Canvas Exercise for topic 2

# %% [markdown]
# Save Your Work
#
# Colab normally saves changes to Google Drive only when you are working with a Drive copy. To keep your completed work, use one of these options:
#
# - Select **File → Save a copy in Drive** to create a copy in your Google Drive.
# - Select **File → Download → Download .ipynb** to save the updated notebook to your computer.
#
# Before finishing, verify that:
#
# - [ ] The notebook opened successfully in Colab.
# - [ ] The runtime connected.
# - [ ] Both code cells ran without errors.
# - [ ] Your name appeared in the final output.
# - [ ] You saved or downloaded the completed notebook.
#
# Submit the completed `.ipynb` file.

# %% [markdown]
# ---
#
# # Graded Assignment Begins Here
#
# > **The following Topic 2 questions are graded.** Complete them by hand and submit them in pdf format

# %% [markdown]
# ## CT4110 – Topic 2 Assignment
# ## From Bits to Qubits
#
# ### Instructions
#
# Complete all questions by hand. **Show all working steps clearly.**
#
# Submit your completed work as a **PDF or clear PNG/image files**.
#
# ---
#
# # Basic
#
# ## Question 1 – Dirac Notation and Qubit States
#
# Consider the following qubit states:
#
# $$
# |0\rangle =
# \begin{bmatrix}
# 1\\
# 0
# \end{bmatrix}
# $$
#
# $$
# |1\rangle =
# \begin{bmatrix}
# 0\\
# 1
# \end{bmatrix}
# $$
#
# ### A.
#
# Consider the following qubit state:
#
# $$
# |\psi\rangle =
# \begin{bmatrix}
# \frac{3}{5}\\
# \frac{4}{5}
# \end{bmatrix}
# $$
#
# Express $|\psi\rangle$ as a linear combination of the computational basis states $|0\rangle$ and $|1\rangle$.
#
# Use:
#
# $$
# |0\rangle =
# \begin{bmatrix}
# 1\\
# 0
# \end{bmatrix}
# $$
#
# and
#
# $$
# |1\rangle =
# \begin{bmatrix}
# 0\\
# 1
# \end{bmatrix}
# $$
#
# ### B.
#
# Write your answer from part (a) in Dirac notation.
#
# Verify that your resulting state is normalised.
#
# ### C.
#
# Express the following qubit state as a linear combination of $|0\rangle$ and $|1\rangle$:
#
# $$
# |\psi\rangle =
# \begin{bmatrix}
# \frac{1}{\sqrt{2}}\\
# \frac{1}{\sqrt{2}}
# \end{bmatrix}
# $$
#
# ### D.
#
# Write your answer from part (b) using Dirac notation.
#
#
# ---
#
# ## Question 2 – Vector Spaces and Normalisation
#
# Consider the state:
#
# $$
# |\psi\rangle =
# \begin{bmatrix}
# \frac{1}{\sqrt{2}}\\
# \frac{1}{\sqrt{2}}
# \end{bmatrix}
# $$
#
# ### A.
#
# Calculate the norm of $|\psi\rangle$.
#
# ### B.
#
# Is $|\psi\rangle$ a valid quantum state? Explain why.
#
# ### C.
#
# Consider:
#
# $$
# |\phi\rangle =
# \begin{bmatrix}
# \frac{1}{2}\\
# \frac{1}{2}
# \end{bmatrix}
# $$
#
# Is $|\phi\rangle$ a valid normalised qubit state?
#
# Show your calculation.
#
# ---
#
# # Medium
#
# ## Question 3 – Inner Product and Orthogonality
#
# Given:
#
# $$
# |0\rangle =
# \begin{bmatrix}
# 1\\
# 0
# \end{bmatrix}
# $$
#
# and
#
# $$
# |1\rangle =
# \begin{bmatrix}
# 0\\
# 1
# \end{bmatrix}
# $$
#
# ### A.
#
# Calculate:
#
# $$
# \langle 0|1\rangle
# $$
#
# ### B.
#
# Calculate:
#
# $$
# \langle 0|0\rangle
# $$
#
# ### C.
#
# Calculate:
#
# $$
# \langle 1|1\rangle
# $$
#
#
# ### D.
#
# Given the quantum states:
#
#
# $$
# |\psi\rangle =
# \frac{1}{\sqrt{2}}
# \begin{bmatrix}
# 1\\
# i
# \end{bmatrix}
# $$
#
# and
#
# $$
# |\phi\rangle =
# \frac{1}{\sqrt{2}}
# \begin{bmatrix}
# i\\
# 1
# \end{bmatrix}
# $$
#
#
#
# Calculate:
#
#
# $$
# \langle \psi|\phi\rangle
# $$
#
#
#
# Are the states $|\psi\rangle$ and $|\phi\rangle$ orthohogonal?
#
# Justify your answer.
#
#
# ---
#
# ## Question 4 – Applying a Quantum Gate
#
# Consider the Pauli-X gate:
#
# $$
# X =
# \begin{bmatrix}
# 0 & 1\\
# 1 & 0
# \end{bmatrix}
# $$
#
# and the initial state:
#
# $$
# |\psi\rangle = |0\rangle =
# \begin{bmatrix}
# 1\\
# 0
# \end{bmatrix}
# $$
#
# ### A.
#
# Calculate:
#
# $$
# X|\psi\rangle
# $$
#
# Perform the matrix multiplication step-by-step.
#
# ### B.
#
# Express the resulting state in Dirac notation.
#
# ### C.
#
# Now apply the X gate to $|1\rangle$:
#
# $$
# X|1\rangle
# $$
#
# Show all working.
#
# ### D.
#
# What does the X gate do to a single qubit?
#
#
# ### E.
#
# Consider the single-qubit state:
#
# $$
# |\psi\rangle =
# \frac{\sqrt{3}}{2}|0\rangle
# +
# \frac{1}{2}|1\rangle
# $$
#
# which can be written in vector form as:
#
# $$
# |\psi\rangle =
# \begin{bmatrix}
# \frac{\sqrt{3}}{2}\\
# \frac{1}{2}
# \end{bmatrix}
# $$
#
# Apply the Pauli-X gate:
#
# $$
# X|\psi\rangle
# $$
#
# Perform the matrix multiplication step-by-step and express the resulting state in Dirac notation.
#
# What effect does the Pauli-X gate have on the amplitudes of $|0\rangle$ and $|1\rangle$?
#
# ---
#
# ## Question 5 – Superposition and the Hadamard Gate
#
# The Hadamard gate is:
#
# $$
# H =
# \frac{1}{\sqrt{2}}
# \begin{bmatrix}
# 1 & 1\\
# 1 & -1
# \end{bmatrix}
# $$
#
# Starting with:
#
# $$
# |\psi\rangle = |0\rangle
# $$
#
# ### A.
#
# Calculate:
#
# $$
# H|0\rangle
# $$
#
# Show the matrix multiplication step-by-step.
#
# ### B.
#
# Express the resulting state as a linear combination of $|0\rangle$ and $|1\rangle$.
#
# ### C.
#
# Calculate the probability of measuring $|0\rangle$.
#
# ### D.
#
# Calculate the probability of measuring $|1\rangle$.
#
#
#
#
# ---
#
# # Advanced
#
# ## Question 6 – Quantum State, Gate and Measurement
#
# A qubit starts in the state:
#
# $$
# |\psi\rangle = |0\rangle
# $$
#
# It is first passed through a Hadamard gate:
#
# $$
# H =
# \frac{1}{\sqrt{2}}
# \begin{bmatrix}
# 1 & 1\\
# 1 & -1
# \end{bmatrix}
# $$
#
# and then through the Pauli-X gate:
#
# $$
# X =
# \begin{bmatrix}
# 0 & 1\\
# 1 & 0
# \end{bmatrix}
# $$
#
# The final state is then measured in the computational basis.
#
# ### A. First Gate
#
# Calculate:
#
# $$
# |\psi_1\rangle = H|0\rangle
# $$
#
# Show all matrix multiplication steps.
#
# ### B. Second Gate
#
# Calculate:
#
# $$
# |\psi_2\rangle = X|\psi_1\rangle
# $$
#
# Show all matrix multiplication steps.
#
# ### C. Final State
#
# Express $|\psi_2\rangle$ in Dirac notation.
#
# ### D. Measurement
#
# Calculate the probability of measuring:
#
# $$
# |0\rangle
# $$
#
# and
#
# $$
# |1\rangle
# $$
